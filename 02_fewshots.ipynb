# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Initialize

# %%
import dspy

# %%
# Clear DSPy's global disk cache
if hasattr(dspy, 'cache') and hasattr(dspy.cache, 'disk_cache'):
    dspy.cache.disk_cache.clear()
    print("clear")
# Out:
# clear

# %%
from package.base import DriverLM, ModelResponse, Usage
import httpx

ollama_client = httpx.Client(timeout=600.0)

def ollama_request_fn(prompt: str | None = None, messages: list[dict] | None = None, temperature: float = 0.0, max_tokens: int = 256) -> dict:
    if messages is None:
        messages = [{"role": "user", "content": prompt}]
    
    response = ollama_client.post(
        'http://localhost:11434/api/chat',
        json={
            "model": "llama3.2-vision:11b",
            "messages": messages,
            "stream": False,
            "options": {"temperature": temperature}
        }
    )
    response.raise_for_status()
    return response.json()  # Return full Ollama response

def ollama_output_fn(response: dict) -> ModelResponse:
    content = response.get("message", {}).get("content", "")
    model = response.get("model", "custom")
    
    usage = Usage(
        prompt_tokens=response.get("prompt_eval_count", 0),
        completion_tokens=response.get("eval_count", 0),
        total_tokens=response.get("prompt_eval_count", 0) + response.get("eval_count", 0)
    )
    
    return ModelResponse.from_text(text=content.strip(), usage=usage, model=model)


custom_lm = DriverLM(
    request_fn=ollama_request_fn,
    output_fn=ollama_output_fn,
    cache=True
)

custom_lm.clear_cache()  # Clear old cache entries

# %% [markdown]
# # Fewshots tuning with BootstrapFewShot

# %%
from dspy.teleprompt import BootstrapFewShot

native_lm = dspy.LM(
    model="ollama/llama3.2-vision:11b",
    api_base="http://localhost:11434",
    temperature=0.0
)
# Configure your DriverLM
lm = custom_lm
# lm = native_lm
dspy.configure(lm=lm)

# Define signature
class Emotion(dspy.Signature):
    """Classify the emotion of a sentence."""
    sentence = dspy.InputField()
    emotion = dspy.OutputField(desc="happy, sad, or neutral")

# Create training data
trainset = [
    dspy.Example(sentence="I love this!", emotion="happy").with_inputs("sentence"),
    dspy.Example(sentence="This is terrible.", emotion="sad").with_inputs("sentence"),
    dspy.Example(sentence="It's okay.", emotion="neutral").with_inputs("sentence"),
]

# Create module
class EmotionClassifier(dspy.Module):
    def __init__(self):
        self.program = dspy.ChainOfThought(Emotion)
    
    def forward(self, sentence):
        return self.program(sentence=sentence)

# Optimize
optimizer = BootstrapFewShot(max_bootstrapped_demos=2, max_labeled_demos=2)
optimized = optimizer.compile(EmotionClassifier(), trainset=trainset)

# Test
result = optimized(sentence="I'm so excited!")
print(f"Emotion: {result.emotion}")
print(f"Reasoning: {result.reasoning}")
optimized(sentence="I love pizza")
# Out:
#  67%|██████▋   | 2/3 [00:01<00:00,  1.53it/s]
# Bootstrapped 2 full traces after 2 examples for up to 1 rounds, amounting to 2 attempts.
# Emotion: happy
# Reasoning: The use of the word "excited" and the exclamation mark convey a strong positive sentiment.
# Prediction(
#     reasoning='The sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").',
#     emotion='happy'
# )

# %%
optimized(sentence="I love pizza")
# Out:
# Prediction(
#     reasoning='The sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").',
#     emotion='happy'
# )

# %%
dspy.inspect_history(n=2)
# Out:
# [2026-01-18T21:07:53.676716]
#
# System message:
#
# Your input fields are:
# 1. `sentence` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `emotion` (str): happy, sad, or neutral
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## sentence ## ]]
# {sentence}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## emotion ## ]]
# {emotion}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Classify the emotion of a sentence.
#
#
# User message:
#
# [[ ## sentence ## ]]
# I love this!
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The use of the exclamation mark and the word "love" convey a strong positive sentiment.
#
# [[ ## emotion ## ]]
# happy
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## sentence ## ]]
# This is terrible.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The sentence contains a strong negative word ("terrible"), indicating a negative tone.
#
# [[ ## emotion ## ]]
# sad
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## sentence ## ]]
# I love pizza
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## emotion ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").
#
# [[ ## emotion ## ]]
# happy
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2026-01-18T21:07:53.718264]
#
# System message:
#
# Your input fields are:
# 1. `sentence` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `emotion` (str): happy, sad, or neutral
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## sentence ## ]]
# {sentence}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## emotion ## ]]
# {emotion}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Classify the emotion of a sentence.
#
#
# User message:
#
# [[ ## sentence ## ]]
# I love this!
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The use of the exclamation mark and the word "love" convey a strong positive sentiment.
#
# [[ ## emotion ## ]]
# happy
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## sentence ## ]]
# This is terrible.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The sentence contains a strong negative word ("terrible"), indicating a negative tone.
#
# [[ ## emotion ## ]]
# sad
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## sentence ## ]]
# I love pizza
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## emotion ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").
#
# [[ ## emotion ## ]]
# happy
#
# [[ ## completed ## ]]

# %%
custom_lm.history
# Out:
# [{'prompt': None,
#   'messages': [{'role': 'system',
#     'content': 'Your input fields are:\n1. `sentence` (str):\nYour output fields are:\n1. `reasoning` (str): \n2. `emotion` (str): happy, sad, or neutral\nAll interactions will be structured in the following way, with the appropriate values filled in.\n\n[[ ## sentence ## ]]\n{sentence}\n\n[[ ## reasoning ## ]]\n{reasoning}\n\n[[ ## emotion ## ]]\n{emotion}\n\n[[ ## completed ## ]]\nIn adhering to this structure, your objective is: \n        Classify the emotion of a sentence.'},
#    {'role': 'user',
#     'content': 'This is an example of the task, though some input or output fields are not supplied.\n\n[[ ## sentence ## ]]\nThis is terrible.'},
#    {'role': 'assistant',
#     'content': '[[ ## reasoning ## ]]\nNot supplied for this particular example. \n\n[[ ## emotion ## ]]\nsad\n\n[[ ## completed ## ]]\n'},
#    {'role': 'user',
#     'content': "This is an example of the task, though some input or output fields are not supplied.\n\n[[ ## sentence ## ]]\nIt's okay."},
#    {'role': 'assistant',
#     'content': '[[ ## reasoning ## ]]\nNot supplied for this particular example. \n\n[[ ## emotion ## ]]\nneutral\n\n[[ ## completed ## ]]\n'},
#    {'role': 'user',
#     'content': '[[ ## sentence ## ]]\nI love this!\n\nRespond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## emotion ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.'}],
#   'kwargs': {},
#   'response': ModelResponse(id='chatcmpl-bbf42366-527d-4f69-85e2-63085bcaaa7e', created=1768745272, model='llama3.2-vision:11b', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content='[[ ## reasoning ## ]]\nThe use of the exclamation mark and the word "love" convey a strong positive sentiment.\n\n[[ ## emotion ## ]]\nhappy\n\n[[ ## completed ## ]]', role='assistant', tool_calls=None, function_call=None, provider_specific_fields=None, reasoning_content=None))], usage={'prompt_tokens': 298, 'completion_tokens': 37, 'total_tokens': 335}, cache_hit=False),
#   'outputs': ['[[ ## reasoning ## ]]\nThe use of the exclamation mark and the word "love" convey a strong positive sentiment.\n\n[[ ## emotion ## ]]\nhappy\n\n[[ ## completed ## ]]'],
#   'usage': {'prompt_tokens': 298,
#    'completion_tokens': 37,
#    'total_tokens': 335},
#   'cost': 0.0,
#   'timestamp': '2026-01-18T21:07:52.227439',
#   'uuid': '020acbae-4b37-4647-a099-44cc2f655f66',
#   'model': 'llama3.2-vision:11b',
#   'response_model': 'llama3.2-vision:11b',
#   'model_type': 'chat'},
#  {'prompt': None,
#   'messages': [{'role': 'system',
#     'content': 'Your input fields are:\n1. `sentence` (str):\nYour output fields are:\n1. `reasoning` (str): \n2. `emotion` (str): happy, sad, or neutral\nAll interactions will be structured in the following way, with the appropriate values filled in.\n\n[[ ## sentence ## ]]\n{sentence}\n\n[[ ## reasoning ## ]]\n{reasoning}\n\n[[ ## emotion ## ]]\n{emotion}\n\n[[ ## completed ## ]]\nIn adhering to this structure, your objective is: \n        Classify the emotion of a sentence.'},
#    {'role': 'user',
#     'content': "This is an example of the task, though some input or output fields are not supplied.\n\n[[ ## sentence ## ]]\nIt's okay."},
#    {'role': 'assistant',
#     'content': '[[ ## reasoning ## ]]\nNot supplied for this particular example. \n\n[[ ## emotion ## ]]\nneutral\n\n[[ ## completed ## ]]\n'},
#    {'role': 'user',
#     'content': '[[ ## sentence ## ]]\nThis is terrible.\n\nRespond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## emotion ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.'}],
#   'kwargs': {},
#   'response': ModelResponse(id='chatcmpl-7f716896-6daf-4242-8ede-79ce354bb3f6', created=1768745272, model='llama3.2-vision:11b', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content='[[ ## reasoning ## ]]\nThe sentence contains a strong negative word ("terrible"), indicating a negative tone.\n\n[[ ## emotion ## ]]\nsad\n\n[[ ## completed ## ]]', role='assistant', tool_calls=None, function_call=None, provider_specific_fields=None, reasoning_content=None))], usage={'prompt_tokens': 236, 'completion_tokens': 34, 'total_tokens': 270}, cache_hit=False),
#   'outputs': ['[[ ## reasoning ## ]]\nThe sentence contains a strong negative word ("terrible"), indicating a negative tone.\n\n[[ ## emotion ## ]]\nsad\n\n[[ ## completed ## ]]'],
#   'usage': {'prompt_tokens': 236,
#    'completion_tokens': 34,
#    'total_tokens': 270},
#   'cost': 0.0,
#   'timestamp': '2026-01-18T21:07:52.690983',
#   'uuid': '148702b4-db91-4c29-bd92-8128f7bd19d5',
#   'model': 'llama3.2-vision:11b',
#   'response_model': 'llama3.2-vision:11b',
#   'model_type': 'chat'},
#  {'prompt': None,
#   'messages': [{'role': 'system',
#     'content': 'Your input fields are:\n1. `sentence` (str):\nYour output fields are:\n1. `reasoning` (str): \n2. `emotion` (str): happy, sad, or neutral\nAll interactions will be structured in the following way, with the appropriate values filled in.\n\n[[ ## sentence ## ]]\n{sentence}\n\n[[ ## reasoning ## ]]\n{reasoning}\n\n[[ ## emotion ## ]]\n{emotion}\n\n[[ ## completed ## ]]\nIn adhering to this structure, your objective is: \n        Classify the emotion of a sentence.'},
#    {'role': 'user', 'content': '[[ ## sentence ## ]]\nI love this!'},
#    {'role': 'assistant',
#     'content': '[[ ## reasoning ## ]]\nThe use of the exclamation mark and the word "love" convey a strong positive sentiment.\n\n[[ ## emotion ## ]]\nhappy\n\n[[ ## completed ## ]]\n'},
#    {'role': 'user', 'content': '[[ ## sentence ## ]]\nThis is terrible.'},
#    {'role': 'assistant',
#     'content': '[[ ## reasoning ## ]]\nThe sentence contains a strong negative word ("terrible"), indicating a negative tone.\n\n[[ ## emotion ## ]]\nsad\n\n[[ ## completed ## ]]\n'},
#    {'role': 'user',
#     'content': "[[ ## sentence ## ]]\nI'm so excited!\n\nRespond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## emotion ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`."}],
#   'kwargs': {},
#   'response': ModelResponse(id='chatcmpl-46ecd80b-7848-4321-9329-9dad71474f90', created=1768745273, model='llama3.2-vision:11b', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content='[[ ## reasoning ## ]]\nThe use of the word "excited" and the exclamation mark convey a strong positive sentiment.\n\n[[ ## emotion ## ]]\nhappy\n\n[[ ## completed ## ]]', role='assistant', tool_calls=None, function_call=None, provider_specific_fields=None, reasoning_content=None))], usage={'prompt_tokens': 282, 'completion_tokens': 38, 'total_tokens': 320}, cache_hit=False),
#   'outputs': ['[[ ## reasoning ## ]]\nThe use of the word "excited" and the exclamation mark convey a strong positive sentiment.\n\n[[ ## emotion ## ]]\nhappy\n\n[[ ## completed ## ]]'],
#   'usage': {'prompt_tokens': 282,
#    'completion_tokens': 38,
#    'total_tokens': 320},
#   'cost': 0.0,
#   'timestamp': '2026-01-18T21:07:53.166804',
#   'uuid': '2cea0cce-0c7f-405f-aa9d-ddd0b7bfb449',
#   'model': 'llama3.2-vision:11b',
#   'response_model': 'llama3.2-vision:11b',
#   'model_type': 'chat'},
#  {'prompt': None,
#   'messages': [{'role': 'system',
#     'content': 'Your input fields are:\n1. `sentence` (str):\nYour output fields are:\n1. `reasoning` (str): \n2. `emotion` (str): happy, sad, or neutral\nAll interactions will be structured in the following way, with the appropriate values filled in.\n\n[[ ## sentence ## ]]\n{sentence}\n\n[[ ## reasoning ## ]]\n{reasoning}\n\n[[ ## emotion ## ]]\n{emotion}\n\n[[ ## completed ## ]]\nIn adhering to this structure, your objective is: \n        Classify the emotion of a sentence.'},
#    {'role': 'user', 'content': '[[ ## sentence ## ]]\nI love this!'},
#    {'role': 'assistant',
#     'content': '[[ ## reasoning ## ]]\nThe use of the exclamation mark and the word "love" convey a strong positive sentiment.\n\n[[ ## emotion ## ]]\nhappy\n\n[[ ## completed ## ]]\n'},
#    {'role': 'user', 'content': '[[ ## sentence ## ]]\nThis is terrible.'},
#    {'role': 'assistant',
#     'content': '[[ ## reasoning ## ]]\nThe sentence contains a strong negative word ("terrible"), indicating a negative tone.\n\n[[ ## emotion ## ]]\nsad\n\n[[ ## completed ## ]]\n'},
#    {'role': 'user',
#     'content': '[[ ## sentence ## ]]\nI love pizza\n\nRespond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## emotion ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.'}],
#   'kwargs': {},
#   'response': ModelResponse(id='chatcmpl-a86154a9-82f0-4010-aa92-5b0928565844', created=1768745273, model='llama3.2-vision:11b', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content='[[ ## reasoning ## ]]\nThe sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").\n\n[[ ## emotion ## ]]\nhappy\n\n[[ ## completed ## ]]', role='assistant', tool_calls=None, function_call=None, provider_specific_fields=None, reasoning_content=None))], usage={'prompt_tokens': 281, 'completion_tokens': 39, 'total_tokens': 320}, cache_hit=False),
#   'outputs': ['[[ ## reasoning ## ]]\nThe sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").\n\n[[ ## emotion ## ]]\nhappy\n\n[[ ## completed ## ]]'],
#   'usage': {'prompt_tokens': 281,
#    'completion_tokens': 39,
#    'total_tokens': 320},
#   'cost': 0.0,
#   'timestamp': '2026-01-18T21:07:53.676716',
#   'uuid': '05d653cf-605c-4c7a-9c95-85b5047e299d',
#   'model': 'llama3.2-vision:11b',
#   'response_model': 'llama3.2-vision:11b',
#   'model_type': 'chat'},
#  {'prompt': None,
#   'messages': [{'role': 'system',
#     'content': 'Your input fields are:\n1. `sentence` (str):\nYour output fields are:\n1. `reasoning` (str): \n2. `emotion` (str): happy, sad, or neutral\nAll interactions will be structured in the following way, with the appropriate values filled in.\n\n[[ ## sentence ## ]]\n{sentence}\n\n[[ ## reasoning ## ]]\n{reasoning}\n\n[[ ## emotion ## ]]\n{emotion}\n\n[[ ## completed ## ]]\nIn adhering to this structure, your objective is: \n        Classify the emotion of a sentence.'},
#    {'role': 'user', 'content': '[[ ## sentence ## ]]\nI love this!'},
#    {'role': 'assistant',
#     'content': '[[ ## reasoning ## ]]\nThe use of the exclamation mark and the word "love" convey a strong positive sentiment.\n\n[[ ## emotion ## ]]\nhappy\n\n[[ ## completed ## ]]\n'},
#    {'role': 'user', 'content': '[[ ## sentence ## ]]\nThis is terrible.'},
#    {'role': 'assistant',
#     'content': '[[ ## reasoning ## ]]\nThe sentence contains a strong negative word ("terrible"), indicating a negative tone.\n\n[[ ## emotion ## ]]\nsad\n\n[[ ## completed ## ]]\n'},
#    {'role': 'user',
#     'content': '[[ ## sentence ## ]]\nI love pizza\n\nRespond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## emotion ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.'}],
#   'kwargs': {},
#   'response': ModelResponse(id='chatcmpl-a86154a9-82f0-4010-aa92-5b0928565844', created=1768745273, model='llama3.2-vision:11b', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content='[[ ## reasoning ## ]]\nThe sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").\n\n[[ ## emotion ## ]]\nhappy\n\n[[ ## completed ## ]]', role='assistant', tool_calls=None, function_call=None, provider_specific_fields=None, reasoning_content=None))], usage={}, cache_hit=True),
#   'outputs': ['[[ ## reasoning ## ]]\nThe sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").\n\n[[ ## emotion ## ]]\nhappy\n\n[[ ## completed ## ]]'],
#   'usage': {},
#   'cost': 0.0,
#   'timestamp': '2026-01-18T21:07:53.718264',
#   'uuid': '962c8b37-df88-4048-9ff3-ddac1f898e09',
#   'model': 'llama3.2-vision:11b',
#   'response_model': 'llama3.2-vision:11b',
#   'model_type': 'chat'}]

# %%
from pathlib import Path

artifact_dir = Path("./artifacts")
artifact_dir.mkdir(parents=True, exist_ok=True)

# 1. Inspect the optimized prompts
print("=== Optimized Module ===")
for name, predictor in optimized.named_predictors():
    print(f"\n{name}:")
    print(f"Signature: {predictor.signature}")
    if hasattr(predictor, 'demos'):
        print(f"Demos: {len(predictor.demos)} examples")
        for i, demo in enumerate(predictor.demos):
            print(f"  Demo {i+1}: {demo}")

# 2. Save the optimized module
filename= artifact_dir / "fewshots_emotion_custom_classifier.json"
optimized.save(filename)
print(f"\nSaved to {filename}")

# 3. Load it later
loaded = EmotionClassifier()
loaded.load(filename)

# 4. Simple inspection
print("\n=== Quick Check ===")
print(f"Module type: {type(optimized)}")
print(f"Has program: {hasattr(optimized, 'program')}")
# Out:
# === Optimized Module ===
#
# program.predict:
# Signature: StringSignature(sentence -> reasoning, emotion
#     instructions='Classify the emotion of a sentence.'
#     sentence = Field(annotation=str required=True json_schema_extra={'__dspy_field_type': 'input', 'prefix': 'Sentence:', 'desc': '${sentence}'})
#     reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#     emotion = Field(annotation=str required=True json_schema_extra={'desc': 'happy, sad, or neutral', '__dspy_field_type': 'output', 'prefix': 'Emotion:'})
# )
# Demos: 2 examples
#   Demo 1: Example({'augmented': True, 'sentence': 'I love this!', 'reasoning': 'The use of the exclamation mark and the word "love" convey a strong positive sentiment.', 'emotion': 'happy'}) (input_keys=None)
#   Demo 2: Example({'augmented': True, 'sentence': 'This is terrible.', 'reasoning': 'The sentence contains a strong negative word ("terrible"), indicating a negative tone.', 'emotion': 'sad'}) (input_keys=None)
#
# Saved to artifacts\fewshots_emotion_custom_classifier.json
#
# === Quick Check ===
# Module type: <class '__main__.EmotionClassifier'>
# Has program: True

# %%
loaded(sentence="I love pizza")
# Out:
# Prediction(
#     reasoning='The sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").',
#     emotion='happy'
# )

# %%
dspy.inspect_history(n=3)
# Out:
# [2026-01-18T21:07:53.676716]
#
# System message:
#
# Your input fields are:
# 1. `sentence` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `emotion` (str): happy, sad, or neutral
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## sentence ## ]]
# {sentence}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## emotion ## ]]
# {emotion}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Classify the emotion of a sentence.
#
#
# User message:
#
# [[ ## sentence ## ]]
# I love this!
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The use of the exclamation mark and the word "love" convey a strong positive sentiment.
#
# [[ ## emotion ## ]]
# happy
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## sentence ## ]]
# This is terrible.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The sentence contains a strong negative word ("terrible"), indicating a negative tone.
#
# [[ ## emotion ## ]]
# sad
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## sentence ## ]]
# I love pizza
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## emotion ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").
#
# [[ ## emotion ## ]]
# happy
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2026-01-18T21:07:53.718264]
#
# System message:
#
# Your input fields are:
# 1. `sentence` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `emotion` (str): happy, sad, or neutral
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## sentence ## ]]
# {sentence}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## emotion ## ]]
# {emotion}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Classify the emotion of a sentence.
#
#
# User message:
#
# [[ ## sentence ## ]]
# I love this!
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The use of the exclamation mark and the word "love" convey a strong positive sentiment.
#
# [[ ## emotion ## ]]
# happy
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## sentence ## ]]
# This is terrible.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The sentence contains a strong negative word ("terrible"), indicating a negative tone.
#
# [[ ## emotion ## ]]
# sad
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## sentence ## ]]
# I love pizza
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## emotion ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").
#
# [[ ## emotion ## ]]
# happy
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2026-01-18T21:07:53.819024]
#
# System message:
#
# Your input fields are:
# 1. `sentence` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `emotion` (str): happy, sad, or neutral
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## sentence ## ]]
# {sentence}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## emotion ## ]]
# {emotion}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Classify the emotion of a sentence.
#
#
# User message:
#
# [[ ## sentence ## ]]
# I love this!
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The use of the exclamation mark and the word "love" convey a strong positive sentiment.
#
# [[ ## emotion ## ]]
# happy
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## sentence ## ]]
# This is terrible.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The sentence contains a strong negative word ("terrible"), indicating a negative tone.
#
# [[ ## emotion ## ]]
# sad
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## sentence ## ]]
# I love pizza
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## emotion ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The sentence contains a positive word ("love") and a topic that is often associated with happiness ("pizza").
#
# [[ ## emotion ## ]]
# happy
#
# [[ ## completed ## ]]
